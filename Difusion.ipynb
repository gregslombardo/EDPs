# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.colors import LinearSegmentedColormap, Normalize  # Import Normalize here

# Crear mapas de colores personalizados
def create_custom_cmap():
    # Rayas gusano: fondo negro y concentraciones verdes
    rayas_gusano_cmap = LinearSegmentedColormap.from_list('rayas_gusano', ['#000000', '#00FF00'])
    
    # Cerebro coral: fondo negro y concentraciones rosa grisáceo claro
    cerebro_coral_cmap = LinearSegmentedColormap.from_list('cerebro_coral', [
        '#000000',  # Negro (fondo)
        '#2E2E2E',  # Gris oscuro
        '#6A5ACD',  # Azul lavanda (transición)
        '#FFC0CB',  # Rosa claro
    ])
    
    return {
        "cerebro_coral": {"F": 0.082, "K": 0.060, "cmap": cerebro_coral_cmap},
        "rayas_gusano": {"F": 0.058, "K": 0.065, "cmap": rayas_gusano_cmap},
        "leopardo": {"F": 0.034, "K": 0.0618, "cmap": "YlOrBr"},  # Amarillo y marrón para leopardo
        "laberintos": {"F": 0.030, "K": 0.0565, "cmap": "binary"},  # Blanco y negro para laberintos
    }

# Obtener los parámetros con los mapas de colores personalizados
PATTERNS = create_custom_cmap()

class ReactionDiffusion:
    def __init__(self, size=512, F=0.03, K=0.0565, cmap="inferno"):
        self.size = size
        self.F = F
        self.K = K
        self.dA = 1.0
        self.dB = 0.5
        self.dt = 0.1  # Paso de tiempo más pequeño para mayor precisión
        
        # Inicializar concentraciones
        self.U, self.V = self.initialize_chemicals()
        
        # Configurar visualización
        self.fig, self.ax = plt.subplots(figsize=(8, 8), dpi=150)
        self.img = self.ax.imshow(
            self.V, 
            cmap=cmap,  # Mapa de colores personalizado
            vmin=0, 
            vmax=1,
            interpolation='bicubic'  # Interpolación suave
        )
        plt.colorbar(self.img)
        self.ax.axis('off')

    def initialize_chemicals(self):
        """Inicializar con manchas aleatorias"""
        U = np.ones((self.size, self.size))
        V = np.zeros((self.size, self.size))
        
        # Añadir 100 manchas aleatorias
        for _ in range(100):
            x = np.random.randint(10, self.size-10)
            y = np.random.randint(10, self.size-10)
            r = np.random.randint(5, 10)  # Tamaño aleatorio de las manchas
            V[x-r:x+r, y-r:y+r] = 0.8 + 0.2 * np.random.randn(2*r, 2*r)
        
        return U, V

    def laplacian(self, Z):
        """Stencil de 5 puntos para la difusión"""
        return (np.roll(Z, (0, -1), (0, 1)) + 
                np.roll(Z, (0, 1), (0, 1)) +
                np.roll(Z, (-1, 0), (0, 1)) + 
                np.roll(Z, (1, 0), (0, 1)) - 
                4 * Z)

    def update(self):
        """Actualización del modelo Gray-Scott"""
        Lu = self.laplacian(self.U)
        Lv = self.laplacian(self.V)
        
        reaction = self.U * self.V**2
        dU = self.dA * Lu - reaction + self.F * (1 - self.U)
        dV = self.dB * Lv + reaction - (self.F + self.K) * self.V
        
        self.U += dU * self.dt
        self.V += dV * self.dt
        
        # Aplicar restricciones
        self.U = np.clip(self.U, 0.1, 1.0)
        self.V = np.clip(self.V, 0.0, 1.0)

    def animate(self, i):
        """Actualización de la animación"""
        for _ in range(5):  # Menos iteraciones por frame para mayor suavidad
            self.update()
        
        self.img.set_data(self.V)
        self.img.set_norm(Normalize(vmin=0, vmax=1))
        
        if i % 10 == 0:
            print(f"Frame {i}: V range = {self.V.min():.2f} - {self.V.max():.2f}")
        
        return [self.img]

    def run(self, pattern_name, save_gif=True):
        """Ejecutar la simulación para un patrón específico"""
        print(f"Simulando patrón: {pattern_name}")
        ani = animation.FuncAnimation(
            self.fig, 
            self.animate, 
            interval=50,  # 20 FPS
            blit=True, 
            save_count=5000  # Más frames para mayor duración
        )
        
        if save_gif:
            # Guardar GIF de alta calidad
            print("Guardando GIF...")
            ani.save(
                f'reaction_diffusion_{pattern_name}.gif', 
                writer='pillow', 
                fps=50, 
                dpi=300,
                bitrate=1800  # Mayor calidad
            )
            print(f"GIF guardado como 'reaction_diffusion_{pattern_name}.gif'")
        
        # Mostrar animación
        plt.show()

# Simular todos los patrones
size = 512  # Tamaño de la cuadrícula (puedes cambiarlo a 512 para mayor resolución)
for pattern_name, params in PATTERNS.items():
    sim = ReactionDiffusion(size=size, F=params["F"], K=params["K"], cmap=params["cmap"])
    sim.run(pattern_name, save_gif=True)
# Out:
# Simulando patrón: cerebro_coral
# Frame 0: V range = 0.00 - 1.00
# Frame 0: V range = 0.00 - 1.00
# Guardando GIF...
# Frame 0: V range = 0.00 - 1.00
# Frame 0: V range = 0.00 - 1.00
# Frame 10: V range = 0.00 - 0.89
# Frame 20: V range = 0.00 - 0.73
# Frame 30: V range = 0.00 - 0.63
# Frame 40: V range = 0.00 - 0.57
# Frame 50: V range = 0.00 - 0.53
# Frame 60: V range = 0.00 - 0.51
# Frame 70: V range = 0.00 - 0.49
# Frame 80: V range = 0.00 - 0.48
# Frame 90: V range = 0.00 - 0.47
# Frame 100: V range = 0.00 - 0.47
# Frame 110: V range = 0.00 - 0.47
# Frame 120: V range = 0.00 - 0.47
# Frame 130: V range = 0.00 - 0.47
# Frame 140: V range = 0.00 - 0.47
# Frame 150: V range = 0.00 - 0.47
# Frame 160: V range = 0.00 - 0.47
# Frame 170: V range = 0.00 - 0.47
# Frame 180: V range = 0.00 - 0.47
# Frame 190: V range = 0.00 - 0.47
# Frame 200: V range = 0.00 - 0.47
# Frame 210: V range = 0.00 - 0.47
# Frame 220: V range = 0.00 - 0.47
# Frame 230: V range = 0.00 - 0.47
# Frame 240: V range = 0.00 - 0.47
# Frame 250: V range = 0.00 - 0.47
# Frame 260: V range = 0.00 - 0.47
# Frame 270: V range = 0.00 - 0.47
# Frame 280: V range = 0.00 - 0.47
# Frame 290: V range = 0.00 - 0.47
# Frame 300: V range = 0.00 - 0.47
# Frame 310: V range = 0.00 - 0.47
# Frame 320: V range = 0.00 - 0.47
# Frame 330: V range = 0.00 - 0.47
# Frame 340: V range = 0.00 - 0.47
# Frame 350: V range = 0.00 - 0.47
# Frame 360: V range = 0.00 - 0.47
# Frame 370: V range = 0.00 - 0.47
# Frame 380: V range = 0.00 - 0.48
# Frame 390: V range = 0.00 - 0.48
# Frame 400: V range = 0.00 - 0.48
# Frame 410: V range = 0.00 - 0.48
# Frame 420: V range = 0.00 - 0.48
# Frame 430: V range = 0.00 - 0.48
# Frame 440: V range = 0.00 - 0.48
# Frame 450: V range = 0.00 - 0.48
# Frame 460: V range = 0.00 - 0.48
# Frame 470: V range = 0.00 - 0.48
# Frame 480: V range = 0.00 - 0.48
# Frame 490: V range = 0.00 - 0.48
# Frame 500: V range = 0.00 - 0.48
# Frame 510: V range = 0.00 - 0.48
# Frame 520: V range = 0.00 - 0.48
# Frame 530: V range = 0.00 - 0.48
# Frame 540: V range = 0.00 - 0.48
# Frame 550: V range = 0.00 - 0.48
# Frame 560: V range = 0.00 - 0.48
# Frame 570: V range = 0.00 - 0.48
# Frame 580: V range = 0.00 - 0.48
# Frame 590: V range = 0.00 - 0.48
# Frame 600: V range = 0.00 - 0.48
# Frame 610: V range = 0.00 - 0.48
# Frame 620: V range = 0.00 - 0.48
# Frame 630: V range = 0.00 - 0.48
# Frame 640: V range = 0.00 - 0.48
# Frame 650: V range = 0.00 - 0.48
# Frame 660: V range = 0.00 - 0.48
# Frame 670: V range = 0.00 - 0.48
# Frame 680: V range = 0.00 - 0.48
# Frame 690: V range = 0.00 - 0.49
# Frame 700: V range = 0.00 - 0.49
# Frame 710: V range = 0.00 - 0.49
# Frame 720: V range = 0.00 - 0.49
# Frame 730: V range = 0.00 - 0.49
# Frame 740: V range = 0.00 - 0.49
# Frame 750: V range = 0.00 - 0.49
# Frame 760: V range = 0.00 - 0.49
# Frame 770: V range = 0.00 - 0.49
# Frame 780: V range = 0.00 - 0.49
# Frame 790: V range = 0.00 - 0.49
# Frame 800: V range = 0.00 - 0.49
# Frame 810: V range = 0.00 - 0.49
# Frame 820: V range = 0.00 - 0.49
# Frame 830: V range = 0.00 - 0.49
# Frame 840: V range = 0.00 - 0.49
# Frame 850: V range = 0.00 - 0.49
# Frame 860: V range = 0.00 - 0.49
# Frame 870: V range = 0.00 - 0.49
# Frame 880: V range = 0.00 - 0.49
# Frame 890: V range = 0.00 - 0.49
# Frame 900: V range = 0.00 - 0.49
# Frame 910: V range = 0.00 - 0.49
# Frame 920: V range = 0.00 - 0.49
# Frame 930: V range = 0.00 - 0.49
# Frame 940: V range = 0.00 - 0.49
# Frame 950: V range = 0.00 - 0.49
# Frame 960: V range = 0.00 - 0.49
# Frame 970: V range = 0.00 - 0.49
# Frame 980: V range = 0.00 - 0.49
# Frame 990: V range = 0.00 - 0.49
# Frame 1000: V range = 0.00 - 0.49
# Frame 1010: V range = 0.00 - 0.49
# Frame 1020: V range = 0.00 - 0.49
# Frame 1030: V range = 0.00 - 0.49
# Frame 1040: V range = 0.00 - 0.49
# Frame 1050: V range = 0.00 - 0.49
# Frame 1060: V range = 0.00 - 0.49
# Frame 1070: V range = 0.00 - 0.49
# Frame 1080: V range = 0.00 - 0.49
# Frame 1090: V range = 0.00 - 0.49
# Frame 1100: V range = 0.00 - 0.49
# Frame 1110: V range = 0.00 - 0.49
# Frame 1120: V range = 0.00 - 0.49
# Frame 1130: V range = 0.00 - 0.49
# Frame 1140: V range = 0.00 - 0.49
# Frame 1150: V range = 0.00 - 0.49
# Frame 1160: V range = 0.00 - 0.49
# Frame 1170: V range = 0.00 - 0.49
# Frame 1180: V range = 0.00 - 0.49
# Frame 1190: V range = 0.00 - 0.49
# Frame 1200: V range = 0.00 - 0.49
# Frame 1210: V range = 0.00 - 0.49
# Frame 1220: V range = 0.00 - 0.49
# Frame 1230: V range = 0.00 - 0.49
# Frame 1240: V range = 0.00 - 0.49
# Frame 1250: V range = 0.00 - 0.49
# Frame 1260: V range = 0.00 - 0.49
# Frame 1270: V range = 0.00 - 0.49
# Frame 1280: V range = 0.00 - 0.49
# Frame 1290: V range = 0.00 - 0.49
# Frame 1300: V range = 0.00 - 0.49
# Frame 1310: V range = 0.00 - 0.49
# Frame 1320: V range = 0.00 - 0.49
# Frame 1330: V range = 0.00 - 0.49
# Frame 1340: V range = 0.00 - 0.49
# Frame 1350: V range = 0.00 - 0.49
# Frame 1360: V range = 0.00 - 0.49
# Frame 1370: V range = 0.00 - 0.49
# Frame 1380: V range = 0.00 - 0.49
# Frame 1390: V range = 0.00 - 0.49
# Frame 1400: V range = 0.00 - 0.49
# Frame 1410: V range = 0.00 - 0.49
# Frame 1420: V range = 0.00 - 0.49
# Frame 1430: V range = 0.00 - 0.49
# Frame 1440: V range = 0.00 - 0.49
# Frame 1450: V range = 0.00 - 0.49
# Frame 1460: V range = 0.00 - 0.49
# Frame 1470: V range = 0.00 - 0.49
# Frame 1480: V range = 0.00 - 0.49
# Frame 1490: V range = 0.00 - 0.49
# Frame 1500: V range = 0.00 - 0.49
# Frame 1510: V range = 0.00 - 0.49
# Frame 1520: V range = 0.00 - 0.49
# Frame 1530: V range = 0.00 - 0.49
# Frame 1540: V range = 0.00 - 0.49
# Frame 1550: V range = 0.00 - 0.49
# Frame 1560: V range = 0.00 - 0.49
# Frame 1570: V range = 0.00 - 0.49
# Frame 1580: V range = 0.00 - 0.49
# Frame 1590: V range = 0.00 - 0.49
# Frame 1600: V range = 0.00 - 0.49
# Frame 1610: V range = 0.00 - 0.49
# Frame 1620: V range = 0.00 - 0.49
# Frame 1630: V range = 0.00 - 0.49
# Frame 1640: V range = 0.00 - 0.49
# Frame 1650: V range = 0.00 - 0.49
# Frame 1660: V range = 0.00 - 0.49
# Frame 1670: V range = 0.00 - 0.49
# Frame 1680: V range = 0.00 - 0.49
# Frame 1690: V range = 0.00 - 0.49
# Frame 1700: V range = 0.00 - 0.49
# Frame 1710: V range = 0.00 - 0.49
# Frame 1720: V range = 0.00 - 0.49
# Frame 1730: V range = 0.00 - 0.49
# Frame 1740: V range = 0.00 - 0.49
# Frame 1750: V range = 0.00 - 0.49
# Frame 1760: V range = 0.00 - 0.49
# Frame 1770: V range = 0.00 - 0.49
# Frame 1780: V range = 0.00 - 0.49
# Frame 1790: V range = 0.00 - 0.49
# Frame 1800: V range = 0.00 - 0.49
# Frame 1810: V range = 0.00 - 0.49
# Frame 1820: V range = 0.00 - 0.49
# Frame 1830: V range = 0.00 - 0.49
# Frame 1840: V range = 0.00 - 0.49
# Frame 1850: V range = 0.00 - 0.49
# Frame 1860: V range = 0.00 - 0.49
# Frame 1870: V range = 0.00 - 0.49
# Frame 1880: V range = 0.00 - 0.49
# Frame 1890: V range = 0.00 - 0.49
# Frame 1900: V range = 0.00 - 0.49
# Frame 1910: V range = 0.00 - 0.49
# Frame 1920: V range = 0.00 - 0.49
# Frame 1930: V range = 0.00 - 0.49
# Frame 1940: V range = 0.00 - 0.49
# Frame 1950: V range = 0.00 - 0.49
# Frame 1960: V range = 0.00 - 0.49
# Frame 1970: V range = 0.00 - 0.49
# Frame 1980: V range = 0.00 - 0.49
# Frame 1990: V range = 0.00 - 0.49
# Frame 2000: V range = 0.00 - 0.49
# Frame 2010: V range = 0.00 - 0.49
# Frame 2020: V range = 0.00 - 0.49
# Frame 2030: V range = 0.00 - 0.49
# Frame 2040: V range = 0.00 - 0.49
# Frame 2050: V range = 0.00 - 0.49
# Frame 2060: V range = 0.00 - 0.49
# Frame 2070: V range = 0.00 - 0.49
# Frame 2080: V range = 0.00 - 0.49
# Frame 2090: V range = 0.00 - 0.49
# Frame 2100: V range = 0.00 - 0.49
# Frame 2110: V range = 0.00 - 0.49
# Frame 2120: V range = 0.00 - 0.49
# Frame 2130: V range = 0.00 - 0.49
# Frame 2140: V range = 0.00 - 0.49
# Frame 2150: V range = 0.00 - 0.49
# Frame 2160: V range = 0.00 - 0.49
# Frame 2170: V range = 0.00 - 0.49
# Frame 2180: V range = 0.00 - 0.49
# Frame 2190: V range = 0.00 - 0.49
# Frame 2200: V range = 0.00 - 0.49
# Frame 2210: V range = 0.00 - 0.49
# Frame 2220: V range = 0.00 - 0.49
# Frame 2230: V range = 0.00 - 0.49
# Frame 2240: V range = 0.00 - 0.49
# Frame 2250: V range = 0.00 - 0.49
# Frame 2260: V range = 0.00 - 0.49
# Frame 2270: V range = 0.00 - 0.49
# Frame 2280: V range = 0.00 - 0.49
# Frame 2290: V range = 0.00 - 0.49
# Frame 2300: V range = 0.00 - 0.49
# Frame 2310: V range = 0.00 - 0.49
# Frame 2320: V range = 0.00 - 0.49
# Frame 2330: V range = 0.00 - 0.49
# Frame 2340: V range = 0.00 - 0.49
# Frame 2350: V range = 0.00 - 0.49
# Frame 2360: V range = 0.00 - 0.49
# Frame 2370: V range = 0.00 - 0.49
# Frame 2380: V range = 0.00 - 0.49
# Frame 2390: V range = 0.00 - 0.49
# Frame 2400: V range = 0.00 - 0.49
# Frame 2410: V range = 0.00 - 0.49
# Frame 2420: V range = 0.00 - 0.49
# Frame 2430: V range = 0.00 - 0.49
# Frame 2440: V range = 0.00 - 0.49
# Frame 2450: V range = 0.00 - 0.49
# Frame 2460: V range = 0.00 - 0.49
# Frame 2470: V range = 0.00 - 0.49
# Frame 2480: V range = 0.00 - 0.49
# Frame 2490: V range = 0.00 - 0.49
# Frame 2500: V range = 0.00 - 0.49
# Frame 2510: V range = 0.00 - 0.49
# Frame 2520: V range = 0.00 - 0.49
# Frame 2530: V range = 0.00 - 0.49
# Frame 2540: V range = 0.00 - 0.49
# Frame 2550: V range = 0.00 - 0.49
# Frame 2560: V range = 0.00 - 0.49
# Frame 2570: V range = 0.00 - 0.49
# Frame 2580: V range = 0.00 - 0.49
# Frame 2590: V range = 0.00 - 0.49
# Frame 2600: V range = 0.00 - 0.49
# Frame 2610: V range = 0.00 - 0.49
# Frame 2620: V range = 0.00 - 0.49
# Frame 2630: V range = 0.00 - 0.49
# Frame 2640: V range = 0.00 - 0.49
# Frame 2650: V range = 0.00 - 0.49
# Frame 2660: V range = 0.00 - 0.49
# Frame 2670: V range = 0.00 - 0.49
# Frame 2680: V range = 0.00 - 0.49
# Frame 2690: V range = 0.00 - 0.49
# Frame 2700: V range = 0.00 - 0.49
# Frame 2710: V range = 0.00 - 0.49
# Frame 2720: V range = 0.00 - 0.49
# Frame 2730: V range = 0.00 - 0.49
